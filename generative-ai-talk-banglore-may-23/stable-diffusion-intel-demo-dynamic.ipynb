# %% [markdown]
# # Quantizing a model with Post Training Dynamic Quantization with Intel Neural Compressor (INC) for text to image tasks

# %% [markdown]
# This notebook shows how to apply post training quantization, using the Intel Neural Compressor (INC) library, for text to image tasks. This is made possible thanks to 🤗 Optimum Intel, an extension of 🤗 Transformers, providing a set of performance optimization tools enabling maximum efficiency to accelerate end-to-end pipelines on a variety of Intel processors.
#
# If you're opening this Notebook on colab, you will probably need to install 🤗 Transformers, 🤗 Datasets, 🤗 Diffusers and 🤗 Optimum.

# %%
#! pip install datasets transformers optimum[neural-compressor]

# %% [markdown]
# The following example applies post-training dynamic quantization on a stable diffusion modelfine-tuned on Pokémon. In this example, we only quantize the unet model which is the performance critical in the diffusion pipeline, the diffusion pipeline has four models: safety_checker, text_encoder, unet, vae

# %%
import argparse
import logging
import math
import os
import sys
import time

import torch
from accelerate.utils import set_seed
from diffusers import StableDiffusionPipeline
from neural_compressor import PostTrainingQuantConfig
from PIL import Image
from pytorch_fid import fid_score
from torch.utils.data import Dataset

from optimum.intel import INCQuantizer, INCStableDiffusionPipeline
from optimum.intel.utils.constant import DIFFUSION_WEIGHTS_NAME

# %%
def image_grid(imgs, rows, cols):
    if not len(imgs) == rows * cols:
        raise ValueError("The specified number of rows and columns are not correct.")

    w, h = imgs[0].size
    grid = Image.new("RGB", size=(cols * w, rows * h))
    grid_w, grid_h = grid.size

    for i, img in enumerate(imgs):
        grid.paste(img, box=(i % cols * w, i // cols * h))
    return grid

# %%
def benchmark(pipeline, generator):
    warmup = 2
    total = 4
    total_time = 0
    with torch.no_grad():
        for i in range(total):
            prompt = "a photo of an astronaut riding a horse on mars"
            start2 = time.time()
            pipeline(prompt, guidance_scale=7.5, num_inference_steps=20, generator=generator).images
            end2 = time.time()
            if i >= warmup:
                total_time += end2 - start2
#             print("Total inference latency: ", str(end2 - start2) + "s")
    print("Average latency: ", (total_time) / (total - warmup), "s")

# %%
pipeline = StableDiffusionPipeline.from_pretrained("lambdalabs/sd-pokemon-diffusers")
# Out:
# safety_checker/model.safetensors not found
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.

# %%
name = "unet"
calibration_text = "a drawing of a gray and black dragon"
num_images_per_prompt = 2
num_inference_steps = 50
output_dir = "output/"
seed = 666
base_images = "base_images/"
_rows = int(math.sqrt(num_images_per_prompt))
generator = torch.Generator("cpu").manual_seed(seed)

def get_fp32_images():
    tmp_fp32_images = "tmp_fp32_images"
    os.makedirs(tmp_fp32_images, exist_ok=True)
    outputs = pipeline(
        calibration_text,
        guidance_scale=7.5,
        num_inference_steps=num_inference_steps,
        generator=generator,
        num_images_per_prompt=num_images_per_prompt,
    )
    fp32_images = outputs.images
    grid = image_grid(fp32_images, rows=_rows, cols=num_images_per_prompt // _rows)
    grid.save(os.path.join(tmp_fp32_images, "fp32.png"))
    return grid

def calibration_func(model):
    calib_num = 5
    setattr(pipeline, name, model)
    with torch.no_grad():
        for i in range(calib_num):
            pipeline(
                calibration_text,
                guidance_scale=7.5,
                num_inference_steps=num_inference_steps,
                generator=generator,
                num_images_per_prompt=num_images_per_prompt,
            )

def eval_func(model):
    setattr(pipeline, name, model)
    generator = torch.Generator("cpu").manual_seed(seed)
    tmp_int8_images = "tmp_int8_images"
    os.makedirs(tmp_int8_images, exist_ok=True)
    with torch.no_grad():
        new_images = pipeline(
            calibration_text,
            guidance_scale=7.5,
            num_inference_steps=num_inference_steps,
            generator=generator,
            num_images_per_prompt=num_images_per_prompt,
        ).images
        if os.path.isfile(os.path.join(tmp_int8_images, "int8.png")):
            os.remove(os.path.join(tmp_int8_images, "int8.png"))
        grid = image_grid(new_images, rows=_rows, cols=num_images_per_prompt // _rows)
        print(grid)
        grid.save(os.path.join(tmp_int8_images, "int8.png"))
        fid = fid_score.calculate_fid_given_paths((base_images, tmp_int8_images), 1, "cpu", 2048, 8)
        return grid, fid

# %%
get_fp32_images()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=1024x512>

# %%
# Create the quantization configuration containing all the quantization parameters
quantization_config = PostTrainingQuantConfig(approach="dynamic") # static or dynamic

pipeline.save_pretrained(output_dir)

# Create a quantizer
quantizer = INCQuantizer.from_pretrained(pipeline.unet, calibration_fn=calibration_func)

# %%
quantizer.quantize(
        quantization_config=quantization_config,
        save_directory=os.path.join(output_dir, "unet"),
        calibration_dataset=None,
        remove_unused_columns=False,
        file_name=DIFFUSION_WEIGHTS_NAME,
    )
# Out:
# 2023-06-10 03:20:42 [INFO] Start auto tuning.
# 2023-06-10 03:20:42 [INFO] Execute the tuning process due to detect the evaluation function.
# 2023-06-10 03:20:42 [INFO] Adaptor has 4 recipes.
# 2023-06-10 03:20:42 [INFO] 0 recipes specified by user.
# 2023-06-10 03:20:42 [INFO] 3 recipes require future tuning.
# 2023-06-10 03:20:42 [INFO] *** Initialize auto tuning
# 2023-06-10 03:20:42 [INFO] {
# 2023-06-10 03:20:42 [INFO]     'PostTrainingQuantConfig': {
# 2023-06-10 03:20:42 [INFO]         'AccuracyCriterion': {
# 2023-06-10 03:20:42 [INFO]             'criterion': 'relative',
# 2023-06-10 03:20:42 [INFO]             'higher_is_better': True,
# 2023-06-10 03:20:42 [INFO]             'tolerable_loss': 0.01,
# 2023-06-10 03:20:42 [INFO]             'absolute': None,
# 2023-06-10 03:20:42 [INFO]             'keys': <bound method AccuracyCriterion.keys of <neural_compressor.config.AccuracyCriterion object at 0x7ff8e89f4280>>,
# 2023-06-10 03:20:42 [INFO]             'relative': 0.01
# 2023-06-10 03:20:42 [INFO]         },
# 2023-06-10 03:20:42 [INFO]         'approach': 'post_training_dynamic_quant',
# 2023-06-10 03:20:42 [INFO]         'backend': 'default',
# 2023-06-10 03:20:42 [INFO]         'calibration_sampling_size': [
# 2023-06-10 03:20:42 [INFO]             100
# 2023-06-10 03:20:42 [INFO]         ],
# 2023-06-10 03:20:42 [INFO]         'device': 'cpu',
# 2023-06-10 03:20:42 [INFO]         'diagnosis': False,
# 2023-06-10 03:20:42 [INFO]         'domain': 'auto',
# 2023-06-10 03:20:42 [INFO]         'example_inputs': None,
# 2023-06-10 03:20:42 [INFO]         'excluded_precisions': [
# 2023-06-10 03:20:42 [INFO]         ],
# 2023-06-10 03:20:42 [INFO]         'framework': 'pytorch_fx',
# 2023-06-10 03:20:42 [INFO]         'inputs': [
# 2023-06-10 03:20:42 [INFO]         ],
# 2023-06-10 03:20:42 [INFO]         'model_name': '',
# 2023-06-10 03:20:42 [INFO]         'op_name_dict': None,
# 2023-06-10 03:20:42 [INFO]         'op_type_dict': None,
# 2023-06-10 03:20:42 [INFO]         'outputs': [
# 2023-06-10 03:20:42 [INFO]         ],
# 2023-06-10 03:20:42 [INFO]         'quant_format': 'default',
# 2023-06-10 03:20:42 [INFO]         'quant_level': 'auto',
# 2023-06-10 03:20:42 [INFO]         'recipes': {
# 2023-06-10 03:20:42 [INFO]             'smooth_quant': False,
# 2023-06-10 03:20:42 [INFO]             'smooth_quant_args': {
# 2023-06-10 03:20:42 [INFO]             },
# 2023-06-10 03:20:42 [INFO]             'fast_bias_correction': False,
# 2023-06-10 03:20:42 [INFO]             'weight_correction': False,
# 2023-06-10 03:20:42 [INFO]             'gemm_to_matmul': True,
# 2023-06-10 03:20:42 [INFO]             'graph_optimization_level': None,
# 2023-06-10 03:20:42 [INFO]             'first_conv_or_matmul_quantization': True,
# 2023-06-10 03:20:42 [INFO]             'last_conv_or_matmul_quantization': True,
# 2023-06-10 03:20:42 [INFO]             'pre_post_process_quantization': True,
# 2023-06-10 03:20:42 [INFO]             'add_qdq_pair_to_weight': False,
# 2023-06-10 03:20:42 [INFO]             'optypes_to_exclude_output_quant': [
# 2023-06-10 03:20:42 [INFO]             ],
# 2023-06-10 03:20:42 [INFO]             'dedicated_qdq_pair': False
# 2023-06-10 03:20:42 [INFO]         },
# 2023-06-10 03:20:42 [INFO]         'reduce_range': None,
# 2023-06-10 03:20:42 [INFO]         'TuningCriterion': {
# 2023-06-10 03:20:42 [INFO]             'max_trials': 100,
# 2023-06-10 03:20:42 [INFO]             'objective': 'performance',
# 2023-06-10 03:20:42 [INFO]             'strategy': 'basic',
# 2023-06-10 03:20:42 [INFO]             'strategy_kwargs': None,
# 2023-06-10 03:20:42 [INFO]             'timeout': 0
# 2023-06-10 03:20:42 [INFO]         },
# 2023-06-10 03:20:42 [INFO]         'use_bf16': True
# 2023-06-10 03:20:42 [INFO]     }
# 2023-06-10 03:20:42 [INFO] }
# 2023-06-10 03:20:42 [WARNING] [Strategy] Please install `mpi4py` correctly if using distributed tuning; otherwise, ignore this warning.
# 2023-06-10 03:20:44 [INFO]  Found 16 blocks
# 2023-06-10 03:20:44 [INFO] Attention Blocks: 16
# 2023-06-10 03:20:44 [INFO] FFN Blocks: 16
# 2023-06-10 03:20:44 [INFO] Pass query framework capability elapsed time: 1538.37 ms
# 2023-06-10 03:20:44 [INFO] Get FP32 model baseline.
# 2023-06-10 03:20:44 [INFO] Save tuning history to /home/ubuntu/demo/nc_workspace/2023-06-10_03-17-55/./history.snapshot.
# 2023-06-10 03:20:44 [INFO] FP32 baseline is: [Accuracy: 1.0000, Duration (seconds): 0.0000]
# 2023-06-10 03:20:44 [INFO] Quantize the model with default config.
# 2023-06-10 03:20:44 [INFO] Fx trace of the entire model failed, We will conduct auto quantization
# 2023-06-10 03:20:52 [INFO] |******Mixed Precision Statistics******|
# 2023-06-10 03:20:52 [INFO] +---------------+-----------+----------+
# 2023-06-10 03:20:52 [INFO] |    Op Type    |   Total   |   INT8   |
# 2023-06-10 03:20:52 [INFO] +---------------+-----------+----------+
# 2023-06-10 03:20:52 [INFO] |     Linear    |    184    |   184    |
# 2023-06-10 03:20:52 [INFO] +---------------+-----------+----------+
# 2023-06-10 03:20:52 [INFO] Pass quantize model elapsed time: 8492.88 ms
# 2023-06-10 03:20:52 [INFO] Tune 1 result is: [Accuracy (int8|fp32): 1.0000|1.0000, Duration (seconds) (int8|fp32): 0.0000|0.0000], Best tune result is: [Accuracy: 1.0000, Duration (seconds): 0.0000]
# 2023-06-10 03:20:52 [INFO] |**********************Tune Result Statistics**********************|
# 2023-06-10 03:20:52 [INFO] +--------------------+----------+---------------+------------------+
# 2023-06-10 03:20:52 [INFO] |     Info Type      | Baseline | Tune 1 result | Best tune result |
# 2023-06-10 03:20:52 [INFO] +--------------------+----------+---------------+------------------+
# 2023-06-10 03:20:52 [INFO] |      Accuracy      | 1.0000   |    1.0000     |     1.0000       |
# 2023-06-10 03:20:52 [INFO] | Duration (seconds) | 0.0000   |    0.0000     |     0.0000       |
# 2023-06-10 03:20:52 [INFO] +--------------------+----------+---------------+------------------+
# 2023-06-10 03:20:52 [INFO] Save tuning history to /home/ubuntu/demo/nc_workspace/2023-06-10_03-17-55/./history.snapshot.
# 2023-06-10 03:20:52 [INFO] Specified timeout or max trials is reached! Found a quantized model which meet accuracy goal. Exit.
# 2023-06-10 03:20:52 [INFO] Save deploy yaml to /home/ubuntu/demo/nc_workspace/2023-06-10_03-17-55/deploy.yaml
# Model weights saved to output/unet/diffusion_pytorch_model.bin
# Configuration saved in output/unet/inc_config.json

# %%
# Create pipeline using the Quantized Model
int8_pipeline = INCStableDiffusionPipeline.from_pretrained(output_dir)

grid, result_optimized_model = eval_func(quantizer._quantized_model)
grid, result_loaded_model = eval_func(int8_pipeline.unet)
# Out:
# /home/ubuntu/miniconda2/envs/optimum/lib/python3.8/site-packages/torch/_utils.py:343: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   device=storage.device,
# Some weights of the model checkpoint at output/unet were not used when initializing UNet2DConditionModel: ['down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_v.module._packed_params._packed_params', 'up_blocks.1.attentions.0.transformer_blocks.0.norm1.module.weight', 'conv_out.module.bias', 'mid_block.attentions.0.transformer_blocks.0.attn2.to_k.module.zero_point', 'up_blocks.0.resnets.2.conv1.module.bias', 'down_blocks.2.attentions.0.transformer_blocks.0.norm2.module.bias', 'up_blocks.2.attentions.2.transformer_blocks.0.attn2.to_q.module._packed_params._packed_params', 'up_blocks.2.resnets.1.conv1.module.bias', 'up_blocks.1.attentions.1.proj_out.module.bias', 'up_blocks.0.resnets.2.conv_shortcut.module.bias', 'down_blocks.2.resnets.0.time_emb_proj.module._packed_params._packed_params', 'mid_block.attentions.0.transformer_blocks.0.ff.net.2.module._packed_params.dtype', 'up_blocks.0.resnets.2.conv2.module.bias', 'down_blocks.2.resnets.1.time_emb_proj.module.scale', 'mid_block.resnets.1.norm2.module.weight', 'up_blocks.1.attentions.2.transformer_blocks.0.ff.net.2.module._packed_params._packed_params', 'up_blocks.3.attentions.1.transformer_blocks.0.attn2.to_v.module._packed_params.dtype', 'up_blocks.0.resnets.0.time_emb_proj.module.zero_point', 'down_blocks.0.resnets.0.time_emb_proj.module.zero_point', 'down_blocks.0.resnets.1.conv1.module.bias', 'down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_v.module._packed_params._packed_params', 'up_blocks.1.attentions.0.transformer_blocks.0.attn1.to_k.module.scale', 'down_blocks.2.attentions.1.transformer_blocks.0.attn2.to_v.module.scale', 'up_blocks.3.attentions.1.proj_out.module.bias', 'down_blocks.0.attentions.1.proj_out.module.weight', 'down_blocks.1.resnets.0.time_emb_proj.module.zero_point', 'down_blocks.0.attentions.0.proj_out.module.bias', 'down_blocks.3.resnets.0.norm1.module.weight', 'up_blocks.1.attentions.2.transformer_blocks.0.norm3.module.bias', 'down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_v.module._packed_params._packed_params', 'down_blocks.2.attentions.0.transformer_blocks.0.attn2.to_q.module._packed_params.dtype', 'up_blocks.0.resnets.2.norm2.module.bias', 'up_blocks.3.attentions.2.transformer_blocks.0.attn2.to_out.0.module.scale', 'up_blocks.2.attentions.0.transformer_blocks.0.attn2.to_q.module._packed_params.dtype', 'up_blocks.2.attentions.1.transformer_blocks.0.attn1.to_out.0.module._packed_params.dtype', 'up_blocks.1.attentions.2.transformer_blocks.0.attn2.to_q.module._packed_params.dtype', 'up_blocks.3.resnets.1.conv_shortcut.module.weight', 'mid_block.attentions.0.transformer_blocks.0.attn1.to_k.module._packed_params.dtype', 'up_blocks.3.attentions.1.transformer_blocks.0.norm1.module.weight', 'down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_out.0.module.zero_point', 'up_blocks.1.attentions.1.transformer_blocks.0.norm2.module.weight', 'up_blocks.1.attentions.0.transformer_blocks.0.attn2.to_out.0.module._packed_params._packed_params', 'down_blocks.2.attentions.1.transformer_blocks.0.attn2.to_v.module.zero_point', 'up_blocks.2.resnets.1.norm2.module.bias', 'up_blocks.1.attentions.1.transformer_blocks.0.attn2.to_q.module.scale', 'down_blocks.2.resnets.0.time_emb_proj.module.zero_point', 'down_blocks.1.resnets.1.norm1.module.bias', 'up_blocks.1.resnets.2.conv_shortcut.module.bias', 'up_blocks.2.attentions.1.transformer_blocks.0.attn1.to_v.module._packed_params._packed_params', 'down_blocks.2.attentions.1.proj_in.module.bias', 'down_blocks.2.attentions.0.transformer_blocks.0.attn2.to_q.module.scale', 'up_blocks.2.attentions.2.proj_in.module.bias', 'up_blocks.1.attentions.2.norm.module.bias', 'down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_v.module._packed_params.dtype', 'down_blocks.1.attentions.1.transformer_blocks.0.attn1.to_k.module.zero_point', 'down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_q.module._packed_params.dtype', 'up_blocks.3.attentions.1.transformer_blocks.0.attn1.to_q.module._packed_params.dtype', ' ...
# - This IS expected if you are initializing UNet2DConditionModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing UNet2DConditionModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of UNet2DConditionModel were not initialized from the model checkpoint at output/unet and are newly initialized: ['down_blocks.2.attentions.1.transformer_blocks.0.ff.net.2.weight', 'up_blocks.2.attentions.0.transformer_blocks.0.norm1.bias', 'down_blocks.0.attentions.0.transformer_blocks.0.norm1.bias', 'up_blocks.0.resnets.1.conv2.bias', 'down_blocks.1.resnets.0.time_emb_proj.bias', 'up_blocks.2.attentions.2.transformer_blocks.0.norm1.bias', 'down_blocks.0.attentions.0.norm.bias', 'down_blocks.2.attentions.1.transformer_blocks.0.norm2.bias', 'up_blocks.1.resnets.1.norm1.bias', 'down_blocks.2.attentions.1.transformer_blocks.0.ff.net.2.bias', 'down_blocks.2.attentions.0.transformer_blocks.0.ff.net.2.weight', 'down_blocks.1.resnets.1.time_emb_proj.weight', 'down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_q.weight', 'mid_block.attentions.0.transformer_blocks.0.attn1.to_out.0.weight', 'up_blocks.2.attentions.1.transformer_blocks.0.attn1.to_q.weight', 'down_blocks.2.resnets.0.norm1.bias', 'down_blocks.1.resnets.1.conv2.bias', 'up_blocks.2.attentions.0.transformer_blocks.0.norm2.bias', 'up_blocks.3.attentions.0.transformer_blocks.0.norm2.bias', 'down_blocks.1.attentions.0.transformer_blocks.0.ff.net.0.proj.bias', 'up_blocks.1.resnets.1.time_emb_proj.weight', 'down_blocks.2.resnets.1.time_emb_proj.bias', 'down_blocks.2.attentions.1.transformer_blocks.0.attn2.to_k.weight', 'up_blocks.2.resnets.2.time_emb_proj.weight', 'up_blocks.3.attentions.2.proj_out.bias', 'up_blocks.2.attentions.2.proj_out.bias', 'up_blocks.3.attentions.2.transformer_blocks.0.norm1.bias', 'time_embedding.linear_2.weight', 'down_blocks.0.resnets.0.norm2.bias', 'up_blocks.1.resnets.0.norm1.bias', 'up_blocks.3.resnets.2.norm1.bias', 'up_blocks.3.attentions.2.transformer_blocks.0.attn1.to_k.weight', 'up_blocks.3.resnets.0.conv2.bias', 'down_blocks.1.attentions.1.transformer_blocks.0.attn2.to_out.0.weight', 'mid_block.attentions.0.transformer_blocks.0.ff.net.0.proj.bias', 'up_blocks.3.resnets.2.conv_shortcut.bias', 'up_blocks.1.attentions.2.transformer_blocks.0.ff.net.2.bias', 'up_blocks.3.attentions.1.transformer_blocks.0.ff.net.2.weight', 'up_blocks.3.resnets.1.time_emb_proj.weight', 'up_blocks.1.attentions.0.transformer_blocks.0.norm1.bias', 'mid_block.attentions.0.norm.bias', 'down_blocks.2.attentions.0.norm.bias', 'up_blocks.2.attentions.1.transformer_blocks.0.attn2.to_out.0.weight', 'down_blocks.2.attentions.0.transformer_blocks.0.norm2.bias', 'down_blocks.2.attentions.1.transformer_blocks.0.attn2.to_out.0.bias', 'up_blocks.1.attentions.0.transformer_blocks.0.attn2.to_q.weight', 'up_blocks.2.attentions.0.transformer_blocks.0.attn2.to_k.weight', 'up_blocks.3.attentions.1.transformer_blocks.0.norm2.bias', 'up_blocks.2.attentions.2.proj_in.bias', 'down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_out.0.bias', 'up_blocks.1.resnets.0.conv_shortcut.bias', 'up_blocks.1.attentions.0.proj_in.bias', 'up_blocks.1.attentions.2.transformer_blocks.0.norm1.bias', 'up_blocks.2.resnets.0.conv1.bias', 'down_blocks.0.attentions.1.transformer_blocks.0.norm3.bias', 'up_blocks.1.attentions.2.transformer_blocks.0.attn1.to_v.weight', 'up_blocks.3.attentions.1.transformer_blocks.0.norm3.bias', 'up_blocks.1.attentions.1.transformer_blocks.0.attn2.to_k.weight', 'up_blocks.3.attentions.2.transformer_blocks.0.attn1.to_q.weight', 'mid_block.resnets.0.conv2.bias', 'mid_block.resnets.1.conv1.bias', 'down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_k.weight', 'up_blocks.1.attentions.2.transformer_blocks.0.ff.net.2.weight', 'up_blocks.2.attentions.2.transformer_blocks.0.attn1.to_v.weight', 'down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_out.0.weight', 'down_blocks.2.attentions.1.norm.bias', 'down_blocks.3.resnets.1.time_emb_proj.bias', 'down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_out.0.weight', 'up_blocks.3.attentions.1.transformer_blocks.0.attn2.to_q.weight', 'up_blocks.2.attentions.1.transformer_blocks.0.attn1.to_k.weight', 'down_blocks. ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# loading configuration file output/unet/inc_config.json
# INCConfig {
#   "distillation": {},
#   "neural_compressor_version": "2.2",
#   "optimum_version": "1.8.6",
#   "pruning": {},
#   "quantization": {
#     "dataset_num_samples": null,
#     "is_static": false
#   },
#   "save_onnx_model": false,
#   "torch_version": "2.1.0.dev20230609+cpu",
#   "transformers_version": "4.30.1"
# }
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=1024x512 at 0x7FF84B40F070>
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.23s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.25s/it]
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=1024x512 at 0x7FF84B40F400>
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.20s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.16s/it]

# %%
if result_loaded_model != result_optimized_model:
    print("The quantized model was not successfully loaded.")
else:
    print("The quantized model was successfully loaded.")
# Out:
# The quantized model was successfully loaded.
